# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("pokemon_data.csv")
dataset
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
plt.figure(figsize =(16,8))
plt.stem(dataset["HP"])
plt.title("HP vs Attack")
plt.xlabel("HP")
plt.ylabel("Attack")
plt.show()

# %%
plt.figure(figsize =(16,8))
plt.style.use('fivethirtyeight')
plt.plot(dataset["#"], dataset["Attack"],color='k', linestyle='--',marker="o", label = "Attack", linewidth = 3)
plt.plot(dataset["#"], dataset["HP"],color='b',linestyle = "-",marker="o", label = "HP")
plt.title("HP vs Attack")
plt.xlabel("HP")
plt.ylabel("Attack")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.figure(figsize =(16,8))
plt.style.use('fivethirtyeight')
plt.plot(dataset["#"], dataset["Attack"],color='k', linestyle='--',marker="o", label = "Attack", linewidth = 3)
plt.plot(dataset["#"], dataset["HP"],color='b',linestyle = "-",marker="o", label = "HP")
plt.title("HP vs Attack")
plt.xlabel("HP")
plt.ylabel("Attack")
plt.legend()
plt.grid(axis = 'x')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

np.random.seed(1)
x = 4 + np.random.normal(0, 1.5, 200)

plt.figure(figsize = (8,8))

plt.hist(x, bins=8, linewidth=0.5, edgecolor="white")

plt.xlim(0,8)
plt.ylim(0,56)
plt.xticks(np.arange(1, 8))
plt.yticks(np.linspace(0, 56, 9))
plt.title("Histogram")
plt.xlabel("Bins")
plt.ylabel("Frequency")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.style.use()
plt.plot()
plt.title()
plt.xlabel()
plt.ylabel()
plt.xlim()
plt.ylim()
plt.xticks()
plt.yticks()
plt.legend()
plt.tight_layout()
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
x = ['A', 'B', 'C', 'D', 'E']
y = [10, 20, 25, 30, 40]

# Create a bar chart
plt.bar(x, y)

# Show the plot
plt.show()

# %%
def planidrome(number):
    return str(number) == str(number)[::-1]

planidrome(121)
# Out:
# True

# %%
planidrome(1212)
# Out:
# False

# %%
def fact(n):
    if n==0 or n ==1:
        return 1
    else:
        return n * fact(n-1)

fact(3)
# Out:
# 6

# %%
fact(4)
# Out:
# 24

# %%
fact(5)
# Out:
# 120

# %%
def sort_list(list1, list2):
    return sorted(list1+list2)

# %%
sort_list([1,2],[0,3,4])
# Out:
# [0, 1, 2, 3, 4]

# %%
list1 = [1, 3, 5, 7]
list2 = [2, 4, 6, 8]
sort_list(list1, list2)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]
